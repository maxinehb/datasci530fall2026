# %% [markdown]
# # Lecture 1 Exercises

# %% [markdown]
# ## Short Questions
#
# <font size = "5">
#
# 1. What is the difference between a list and an array?
# 2. Consider the list <br>
#
# ```list_colors = ["red","yellow","green"]``` <br>
#
# What is the output of ```list_colors[0]``` and <br>
# ```list_colors[1]```?
#
# 3. How do you concatenate two strings?
# 4. What does the error "not defined" mean?
# 5. What does the error "could not be broadcast" mean?
# 6. How do you compute the median of an array?

# %%
# Write your answers here as comments:
# 1. An array is the numeric object verison of a list [1,2,3]. An array is a vector. A list can store elements of different data types at the same time. 
#    Arrays are better for operations as they store elements that are the same data type. Lists are always denoted by square brackets.

list_colors = ["red", "yellow", "green"]
print(list_colors[0])
print(list_colors[1])
# 2. list_colors[0] outputs red, list_colors[1] outputs yellow.

# 3. You concatenate two strings by combining them into one string with the + operator to combine different strings and can add space in between them too 
#    by doing + " " +.

# 4. The error "not defined" means the variable is being called before it has been defined. There is no data/value assigned to the variable yet.

# 5. The error "could not be broadcast" means that two arrays don't have the same size/shape so the operation cannot be performed.

# 6. np.median()
# Out:
# red
# yellow

# %% [markdown]
# ## Long Questions

# %% [markdown]
# <font size = "5">
#
# (a) Import the pandas, matplotlib, and numpy packages

# %%
# Write your own code
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# (b) Open the dataset "worldbank_wdi_2019.csv" <br>
# in the "data" folder
#
# <font size = "3">
#
# - Read it as a pandas object called "wdi"
# - Note: This is a subset of the World Development Indicators for 2019
# - Each observation represents a different country

# %%
# Write your own code

# Read it as a pandas object called "wdi"
wdi = pd.read_csv("data/worldbank_wdi_2019.csv")

print(wdi.head())
# Out:
#    year    country_name  life_expectancy  gdp_per_capita_usd
# 0  2019     Afghanistan           63.565          500.522664
# 1  2019         Albania           79.282         5396.215864
# 2  2019         Algeria           76.474         4022.150184
# 3  2019  American Samoa              NaN        13672.576660
# 4  2019         Andorra              NaN        41327.502030

# %% [markdown]
# <font size = "5">
#
# (c) Browse the dataset and manually create <br>
# a list of variable names

# %%
# Write your own code

# Create a list, e.g. "variable_names = [ "name1", "name2", "name3" ]"
# Manually type the names of the variables
# If you're viewing the dataset from the VS-Code "Variables" tool, you'll
# see an extra column "index". Do not include this in your list.

print(wdi.head())

variable_names = ["year", "country_name", "life_expectancy", "gdp_per_capita_usd"]
# Out:
#    year    country_name  life_expectancy  gdp_per_capita_usd
# 0  2019     Afghanistan           63.565          500.522664
# 1  2019         Albania           79.282         5396.215864
# 2  2019         Algeria           76.474         4022.150184
# 3  2019  American Samoa              NaN        13672.576660
# 4  2019         Andorra              NaN        41327.502030

# %% [markdown]
# <font size = "5">
#
# (d) Compute descriptive statistics for the fourth <br>
# variable in the dataset
#
# <font size = "3">
#
# - One way to do this is:
#
# wdi["gdp_per_capita_usd"].describe()
#
# - Do something similar, but with the list you created above.
# - Substitute "gdp_per_capita_usd" with a command that <br>
# automatically extracts the fourth element in the list

# %%
# Write your own code

# Remember that the numbering in Python starts at zero
# For example:
# list_colors = ["red","green","yellow"]
# list_colors[2] will output "yellow"


fourth_variable = variable_names[3]

stats = wdi[fourth_variable].describe()
print(stats)
# Out:
# count       255.000000
# mean      17230.949757
# std       25792.183785
# min         216.972968
# 25%        2186.046581
# 50%        6837.717826
# 75%       19809.323135
# max      199377.481800
# Name: gdp_per_capita_usd, dtype: float64

# %% [markdown]
# <font size = "5">
#
# (e) Show a scatter plot that shows "gdp_per_capita_usd" <br>
# in the x-axis and "life_expectancy" in the y-axis. Label the axes.

# %%
# Write your own code

plt.scatter(x = wdi['gdp_per_capita_usd'], y = wdi['life_expectancy'])
plt.xlabel("GDP per Capita (USD)")
plt.ylabel("Life Expectancy (Years)")

plt.show()

# %% [markdown]
# <font size = "5">
#
# (f) Generate "vec_x" from a chi-square <br>
# distribution with (df = 1, size = 1000)
#
# <font size = "3">
#
# - Plot a histogram of each variable, with axis labels, and title
# - Create a new variable "vec_y" by the formula <br>
# $ y = e^x + 2x + 5$
# - Plot "vec_x" against "vec_y" and label the axes

# %%
# Write your own code

vec_x = np.random.chisquare(df=1, size=1000)

# histogram of vec_x
plt.hist(vec_x)
plt.xlabel("vec_x")
plt.ylabel("Frequency")
plt.title("Histogram of vec_x")
plt.show()


vec_y = np.exp(vec_x) + 2 * vec_x + 5

# histogram of vec_y
plt.hist(vec_y)
plt.xlabel("vec_y")
plt.ylabel("Frequency")
plt.title("Histogram of vec_y")
plt.show()

# vec_x and vec_y
plt.scatter(vec_x, vec_y)
plt.xlabel("vec_x")
plt.ylabel("vec_y")
plt.show()

# %% [markdown]
# <font size = "5">
#
# (g) Research online how to create an array with <br>
# ```size = 1000``` entries, with all entries equal to one.
#
# <font size = "3">
#
# - Create a new matrix, ```X_mat``` that appends a <br>
# vector with only ones and "vec_x" from question (f) to form <br>
# a matrix with two columns and 1000 rows
# - Compute $(X_{mat}'X_{mat})^{-1}$

# %%
# Write your own code
# Create an array with 1000 entries, all equal to one
ones_vector = np.ones(1000)

# Combine ones_vector and vec_x to form X_mat
X_mat = np.column_stack((ones_vector, vec_x))

# Compute inverse of (X_mat'X_mat)
X_mat_transpose = X_mat.T
X_mat_product = np.dot(X_mat_transpose, X_mat)
det = np.linalg.det(X_mat_product)
print(det)
X_mat_inverse = np.linalg.inv(X_mat_product)

print(X_mat_inverse)
# Out:
# 1857960.068066549
# [[ 0.00148343 -0.00051009]
#  [-0.00051009  0.00053822]]
